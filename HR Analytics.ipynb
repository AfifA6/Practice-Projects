# %% [markdown]
# ## HR Analytics Project

# %% [markdown]
# ### Project Description

# %% [markdown]
# Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# #### HR Analytics
# Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# #### Attrition in HR
# Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.

# %% [markdown]
# #### Attrition affecting Companies
# A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Data set

# %%
df = pd.read_csv(r"D:\Assignments\WA_Fn-UseC_-HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# ### EDA

# %%
#Checking shape
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# This shows the shape of the data set i.e. 1470 rows and 35 columns.

# %%
#Checking columns
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# This shows the column names present in the data set.

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# This shows the null values present in the data set (if any).

# %%
#Checking data types
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# This shows the data types present in the data set.

# %%
#Checking the value counts of each column
for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
#
#
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
#
#
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# 691     6
# 408     5
# 530     5
# 1329    5
# 1082    5
#        ..
# 650     1
# 279     1
# 316     1
# 314     1
# 628     1
# Name: DailyRate, Length: 886, dtype: int64
#
#
# Research & Development    961
# Sales                     446
# Human Resources            63
# ...

# %% [markdown]
# No white spaces or null values for now.

# %% [markdown]
# Since the columns EmployeeCount and StandardHours have only one value, let's just drop it.

# %%
df.drop(['EmployeeCount', 'StandardHours'], axis=1, inplace=True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  ... PerformanceRating  RelationshipSatisfaction  \
# 0                        2  ...                 3                         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %% [markdown]
# It gives the information about the no. of rows & columns, column names, non-null values, data types and memory usage.

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925
# std       9.135373   403.509100          8.106864     1.024165
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000
# 50%      36.000000   802.000000          7.000000     3.000000
# 75%      43.000000  1157.000000         14.000000     4.000000
# max      60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# std        602.024335                 1.093082    20.329428        0.711561
# min          1.000000                 1.000000    30.000000        1.000000
# ...

# %% [markdown]
# It gives the statistical information about the data set.

# %%
#Checking for categorical columns
cat_col = []
for i in df.dtypes.index:
    if df.dtypes[i] == "object":
        cat_col.append(i)
print("Categorical columns:", cat_col)
print("\n")
# Out:
# Categorical columns: ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']

# %% [markdown]
# It shows all the categorical columns present in the data set.

# %%
#Checking for numerical columns
num_col = []
for i in df.dtypes.index:
    if df.dtypes[i] == "int64":
        num_col.append(i)
print("Numerical columns:", num_col)
print("\n")
# Out:
# Numerical columns: ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# It shows all the numerical columns present in the data set.

# %% [markdown]
# ### Checking for Correlation

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# ...

# %%
#Let's plot a heatmap for visualizing correlation
plt.figure(figsize=(15, 8))
sns.heatmap(df.corr(), annot=True, linewidth=0.5, cmap='magma')
plt.show()

# %% [markdown]
# From the above heatmap we can notice that MonthlyIncome and JobLevel have the highest correlation of 95% between each other, TotalWorkingYears has 78% with JobLevel and 77% with Monthly Income, YearsWithCurrManager has 77% correlation with YearAtCompany and 71% with YearsInCurrentRole & 51% with YearsSinceLastPromotion.

# %% [markdown]
# ### Data Visualization

# %%
#Visualizing the label
ax = sns.countplot(x='Attrition', data=df)
print(df['Attrition'].value_counts())
plt.show()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# In HR, Attrition means the gradual loss of employees overtime. And here we can see that the employees who do not have attrition are very less in number as compared to those having attrition.

# %%
#Comparing Age with Attrition
sns.stripplot(x='Attrition', y='Age', data=df, palette='colorblind')   
plt.show()

# %% [markdown]
# Here, we can see that those with the range between 20-60 have attrition and it's little lesser than those without having attrition.

# %%
#Visualizing BusinessTravel
ax = sns.countplot(x='BusinessTravel', data=df)
print(df['BusinessTravel'].value_counts())
plt.show()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# Here, we can see that those who travel rarely are much more in numbers than those who travel frequently and non-travelers.

# %%
#Comparing DailyRate with Attrition
sns.stripplot(x='Attrition', y='DailyRate', data=df, palette='colorblind')   
plt.show()

# %% [markdown]
# Here, we can see that DailyRate is slightly lesser in employees having attrition and more in those having no attrition.

# %%
#Visualizing Department
ax = sns.countplot(x='Department', data=df)
print(df['Department'].value_counts())
plt.show()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %% [markdown]
# We can see that much more number of employees are in the R & D Department followed by Sales and HR Departments.

# %%
#Visualizing Employees' Education
ax = sns.countplot(x='Education', data=df)
print(df['Education'].value_counts())
plt.show()
# Out:
# 3    572
# 4    398
# 2    282
# 1    170
# 5     48
# Name: Education, dtype: int64

# %%
#Visualizing Education Field
ax = sns.countplot(x='EducationField', data=df)
print(df['EducationField'].value_counts())
plt.show()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [markdown]
# We can see that much more number of employees have Life Sciences background followed by Medical Education.

# %%
#Comparing EmployeeNumber with Attrition
sns.stripplot(x='Attrition', y='EmployeeNumber', data=df, palette='colorblind')   
plt.show()

# %% [markdown]
# We can see that most of the employees don't have any attrition.

# %%
#Visualizing EnvironmentSatisfaction
ax = sns.countplot(x='EnvironmentSatisfaction', data=df)
print(df['EnvironmentSatisfaction'].value_counts())
plt.show()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %% [markdown]
# Here, 3 & 4 are more in number as compared to 1 & 2.

# %%
#Visualizing Gender w.r.t Attrition
ax = sns.countplot(x='Gender', data=df, hue='Attrition')
print(df['Gender'].value_counts())
plt.show()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# Here, we can see that males have more attrition than females.

# %%
#Comparing HourlyRate with Attrition
sns.stripplot(x='Attrition', y='HourlyRate', data=df, palette='colorblind')   
plt.show()

# %%
#Visualizing JobInvolvement w.r.t Attrition
ax = sns.countplot(x='JobInvolvement', data=df, hue='Attrition')
print(df['JobInvolvement'].value_counts())
plt.show()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
#Visualizing JobLevel w.r.t Attrition
ax = sns.countplot(x='JobLevel', data=df, hue='Attrition')
print(df['JobLevel'].value_counts())
plt.show()
# Out:
# 1    543
# 2    534
# 3    218
# 4    106
# 5     69
# Name: JobLevel, dtype: int64

# %% [markdown]
# Job Level 1 has more attrition as compared to others.

# %%
#Visualizing JobRole w.r.t Attrition
ax = sns.countplot(x='JobRole', data=df, hue='Attrition')
print(df['JobRole'].value_counts())
plt.show()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [markdown]
# Here, Laboratory Technician has the highest attrition followed by Sales Executive and Research Scientist. etc.

# %%
#Visualizing JobSatisfaction w.r.t Attrition
ax = sns.countplot(x='JobSatisfaction', data=df, hue='Attrition')
print(df['JobSatisfaction'].value_counts())
plt.show()
# Out:
# 4    459
# 3    442
# 1    289
# 2    280
# Name: JobSatisfaction, dtype: int64

# %%
#Visualizing MaritalStatus w.r.t Attrition
ax = sns.countplot(x='MaritalStatus', data=df, hue='Attrition')
print(df['MaritalStatus'].value_counts())
plt.show()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# Here, we can notice that Single employees have more amount of Attrition than others and Divorced has the least.

# %%
#Comparing MonthlyIncome with Attrition
sns.stripplot(x='Attrition', y='MonthlyIncome', data=df, palette='colorblind')   
plt.show()

# %% [markdown]
# Monthly Income has less amount of attrition.

# %%
#Comparing MonthlyRate with Attrition
sns.stripplot(x='Attrition', y='MonthlyRate', data=df, palette='colorblind')   
plt.show()

# %%
#Visualizing NumCompaniesWorked w.r.t Attrition
ax = sns.countplot(x='NumCompaniesWorked', data=df, hue='Attrition')
print(df['NumCompaniesWorked'].value_counts())
plt.show()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %% [markdown]
# Type 1 has more attrition compared with others.

# %%
#Visualizing Over18 w.r.t Attrition
ax = sns.countplot(x='Over18', data=df, hue='Attrition')
print(df['Over18'].value_counts())
plt.show()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %% [markdown]
# Here, there is very less amount of attrition.

# %%
#Visualizing OverTime w.r.t Attrition
ax = sns.countplot(x='OverTime', data=df, hue='Attrition')
print(df['OverTime'].value_counts())
plt.show()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# Those who work overtime have slightly more attrition.

# %%
#Visualizing PercentSalaryHike w.r.t Attrition
ax = sns.countplot(x='PercentSalaryHike', data=df, hue='Attrition')
print(df['PercentSalaryHike'].value_counts())
plt.show()
# Out:
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: PercentSalaryHike, dtype: int64

# %% [markdown]
# We can see 11 & 13 percent salary hike has more amount of attrition.

# %%
#Visualizing PerformanceRating w.r.t Attrition
ax = sns.countplot(x='PerformanceRating', data=df, hue='Attrition')
print(df['PerformanceRating'].value_counts())
plt.show()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# 3 has more attrition than 4.

# %%
#Visualizing RelationshipSatisfaction w.r.t Attrition
ax = sns.countplot(x='RelationshipSatisfaction', data=df, hue='Attrition')
print(df['RelationshipSatisfaction'].value_counts())
plt.show()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
#Visualizing StockOptionLevel w.r.t Attrition
ax = sns.countplot(x='StockOptionLevel', data=df, hue='Attrition')
print(df['StockOptionLevel'].value_counts())
plt.show()
# Out:
# 0    631
# 1    596
# 2    158
# 3     85
# Name: StockOptionLevel, dtype: int64

# %%
#Visualizing TotalWorkingYears with Attrition
sns.stripplot(x='Attrition', y='TotalWorkingYears', data=df, palette='colorblind')   
plt.show()

# %%
#Visualizing TrainingTimesLastYear with Attrition
ax = sns.countplot(x='TrainingTimesLastYear', data=df, hue='Attrition')
print(df['TrainingTimesLastYear'].value_counts())
plt.show()
# Out:
# 2    547
# 3    491
# 4    123
# 5    119
# 1     71
# 6     65
# 0     54
# Name: TrainingTimesLastYear, dtype: int64

# %%
#Visualizing WorkLifeBalance with Attrition
ax = sns.countplot(x='WorkLifeBalance', data=df, hue='Attrition')
print(df['WorkLifeBalance'].value_counts())
plt.show()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
#Visualizing YearsAtCompany with Attrition
sns.stripplot(x='Attrition', y='YearsAtCompany', data=df, palette='colorblind')   
plt.show()

# %%
#Visualizing YearInCurrentRole with Attrition
ax = sns.countplot(x='YearsInCurrentRole', data=df, hue='Attrition')
print(df['YearsInCurrentRole'].value_counts())
plt.show()
# Out:
# 2     372
# 0     244
# 7     222
# 3     135
# 4     104
# 8      89
# 9      67
# 1      57
# 6      37
# 5      36
# 10     29
# 11     22
# 13     14
# 14     11
# 12     10
# 15      8
# 16      7
# 17      4
# 18      2
# Name: YearsInCurrentRole, dtype: int64

# %%
#Visualizing YearsSinceLastPromption with Attrition
ax = sns.countplot(x='YearsSinceLastPromotion', data=df, hue='Attrition')
print(df['YearsSinceLastPromotion'].value_counts())
plt.show()
# Out:
# 0     581
# 1     357
# 2     159
# 7      76
# 4      61
# 3      52
# 5      45
# 6      32
# 11     24
# 8      18
# 9      17
# 15     13
# 13     10
# 12     10
# 14      9
# 10      6
# Name: YearsSinceLastPromotion, dtype: int64

# %%
#Visualizing YearsWithCurrManager with Attrition
ax = sns.countplot(x='YearsWithCurrManager', data=df, hue='Attrition')
print(df['YearsWithCurrManager'].value_counts())
plt.show()
# Out:
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: YearsWithCurrManager, dtype: int64

# %% [markdown]
# ### Checking for Outliers

# %%
num_col
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
#Checking for outliers by box plot
plt.figure(figsize= (10, 6), facecolor="white")
plotnumber=1
for col in num_col:
    if plotnumber<=24:
        ax = plt.subplot(4,6,plotnumber)
        sns.boxplot(df[col], palette = "Set2_r")
        plt.xlabel(col, fontsize=8)
    
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# We can notice some oultiers present in the dataset.

# %% [markdown]
# ### Checking for Skewness

# %%
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# YearsWithCurrManager        0.833451
# dtype: float64

# %% [markdown]
# We can notice some skewness in our data such as in DistanceFromHome, JobLevel, MonthlyIncome, NumCompaniesWorked, PercentSalaryHike, PerformanceRating, StockOptionLevel, TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion and YearsWithCurrManager. Let's reduce them.

# %%
#Reducing skewness by transformation methods
df['DistanceFromHome'] = np.sqrt(df['DistanceFromHome'])

df['JobLevel'] = np.cbrt(df['JobLevel'])

df['MonthlyIncome'] = np.cbrt(df['MonthlyIncome'])

df['NumCompainesWorked'] = np.cbrt(df['NumCompaniesWorked'])

df['PercentSalaryHike'] = np.sqrt(df['PercentSalaryHike'])

df['PerformanceRating'] = np.cbrt(df['PerformanceRating'])

df['StockOptionLevel'] = np.sqrt(df['StockOptionLevel'])

df['TotalWOrkingYears'] = np.cbrt(df['TotalWorkingYears'])

df['YearsAtCompany'] = np.cbrt(df['YearsAtCompany'])

df['YearsInCurrentRole'] = np.sqrt(df['YearsInCurrentRole'])

df['YearsSinceLastPromotion'] = np.cbrt(df['YearsSinceLastPromotion'])

df['YearsWithCurrManager'] = np.sqrt(df['YearsWithCurrManager'])

# %%
#Let's check
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.398114
# Education                  -0.289681
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.460775
# JobSatisfaction            -0.329672
# MonthlyIncome               0.677032
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.655412
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.057528
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.367351
# YearsInCurrentRole         -0.254344
# YearsSinceLastPromotion     0.198634
# YearsWithCurrManager       -0.254611
# NumCompainesWorked         -0.699002
# ...

# %%
#There are still some skewness left. Let's reduce it again.
df['NumCompaniesWorked'] = np.cbrt(df['NumCompaniesWorked'])

df['PerformanceRating'] = np.log(df['PerformanceRating'])

df['TotalWorkingYears'] = np.cbrt(df['TotalWorkingYears'])

# %%
#Let's check
df.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.398114
# Education                  -0.289681
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    0.460775
# JobSatisfaction            -0.329672
# MonthlyIncome               0.677032
# MonthlyRate                 0.018578
# NumCompaniesWorked         -0.699002
# PercentSalaryHike           0.655412
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.057528
# TotalWorkingYears          -0.395296
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany             -0.367351
# YearsInCurrentRole         -0.254344
# YearsSinceLastPromotion     0.198634
# YearsWithCurrManager       -0.254611
# NumCompainesWorked         -0.699002
# ...

# %% [markdown]
# Now everything looks good. Let's proceed further.

# %% [markdown]
# ### Encoding Categorical Column

# %%
#Encoding categorical column using OrdinalEncoder

from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1, 1))
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0          1.000000
# 1      49        0.0             1.0        279         1.0          2.828427
# 2      37        1.0             2.0       1373         1.0          1.414214
# 3      33        0.0             1.0       1392         1.0          1.732051
# 4      27        0.0             2.0        591         1.0          1.414214
# ...   ...        ...             ...        ...         ...               ...
# 1465   36        0.0             1.0        884         1.0          4.795832
# 1466   39        0.0             2.0        613         1.0          2.449490
# 1467   27        0.0             2.0        155         1.0          2.000000
# 1468   49        0.0             1.0       1023         2.0          1.414214
# 1469   34        0.0             2.0        628         1.0          2.828427
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   float64
#  2   BusinessTravel            1470 non-null   float64
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   float64
#  5   DistanceFromHome          1470 non-null   float64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   float64
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   float64
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# We can see all our data have been converted to numerical.

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1470.000000  1470.000000     1470.000000     1470.000000
# mean           2.725944     2.912925        2.247619     1024.865306
# std            1.327760     1.024165        1.331369      602.024335
# ...

# %%
#Checking correlation
cor = df.corr()
cor
# Out:
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.159205        0.024751   0.010661
# Attrition                -0.159205   1.000000        0.000074  -0.056652
# BusinessTravel            0.024751   0.000074        1.000000  -0.004086
# DailyRate                 0.010661  -0.056652       -0.004086   1.000000
# Department               -0.031882   0.063991       -0.009044   0.007109
# DistanceFromHome         -0.013684   0.079576       -0.015805  -0.003880
# Education                 0.208034  -0.031373        0.000757  -0.016806
# EducationField           -0.040873   0.026846        0.023724   0.037709
# EmployeeNumber           -0.010145  -0.010577       -0.015578  -0.050990
# EnvironmentSatisfaction   0.010146  -0.103369        0.004174   0.018355
# Gender                   -0.036311   0.029453       -0.032981  -0.011716
# HourlyRate                0.024287  -0.006846        0.026528   0.023381
# ...

# %%
#Visualizing correlation by plotting a heatmap
plt.figure(figsize = (20, 15))
sns.heatmap(df.corr(), linewidths = 0.1, fmt=".1g", linecolor = "black", annot = True, cmap = "Blues_r")
plt.yticks(rotation=0)
plt.show()

# %%
cor['Attrition'].sort_values(ascending = False)
# Out:
# Attrition                   1.000000
# OverTime                    0.246118
# MaritalStatus               0.162070
# DistanceFromHome            0.079576
# JobRole                     0.067151
# Department                  0.063991
# NumCompainesWorked          0.044984
# NumCompaniesWorked          0.044984
# Gender                      0.029453
# EducationField              0.026846
# MonthlyRate                 0.015170
# PerformanceRating           0.002889
# BusinessTravel              0.000074
# HourlyRate                 -0.006846
# EmployeeNumber             -0.010577
# PercentSalaryHike          -0.015557
# Education                  -0.031373
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.055223
# DailyRate                  -0.056652
# TrainingTimesLastYear      -0.059478
# WorkLifeBalance            -0.063939
# EnvironmentSatisfaction    -0.103369
# JobSatisfaction            -0.103481
# JobInvolvement             -0.130016
# ...

# %% [markdown]
# Everything looks good, let's move ahead.

# %% [markdown]
# ### Separating Features and Label

# %%
x = df.drop("Attrition", axis=1)
y = df["Attrition"]

# %%
print(x.shape)
print(y.shape)
# Out:
# (1470, 34)
# (1470,)

# %% [markdown]
# ### Feature Scaling Using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.446350        0.590048   0.742527    1.401512         -1.300333
# 1     1.322365       -0.913194  -1.297775   -0.493817          0.077211
# 2     0.008343        0.590048   1.414363   -0.493817         -0.988263
# 3    -0.429664       -0.913194   1.461466   -0.493817         -0.748803
# 4    -1.086676        0.590048  -0.524295   -0.493817         -0.988263
# ...        ...             ...        ...         ...               ...
# 1465 -0.101159       -0.913194   0.202082   -0.493817          1.559462
# 1466  0.227347        0.590048  -0.469754   -0.493817         -0.208282
# 1467 -1.086676        0.590048  -1.605183   -0.493817         -0.546929
# 1468  1.322365       -0.913194   0.546677    1.401512         -0.988263
# 1469 -0.320163        0.590048  -0.432568   -0.493817          0.077211
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# We have scaled our data to reduce biasness.

# %% [markdown]
# ### Checking for VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF Values"] = [variance_inflation_factor(x.values, i)
                    for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF Values                  Features
# 0     2.019918                       Age
# 1     1.020013            BusinessTravel
# 2     1.025120                 DailyRate
# 3     1.967118                Department
# 4     1.016345          DistanceFromHome
# 5     1.065531                 Education
# 6     1.018182            EducationField
# 7     1.024160            EmployeeNumber
# 8     1.021883   EnvironmentSatisfaction
# 9     1.021950                    Gender
# 10    1.023077                HourlyRate
# 11    1.022162            JobInvolvement
# 12    8.967312                  JobLevel
# 13    1.908494                   JobRole
# 14    1.022554           JobSatisfaction
# 15    2.331785             MaritalStatus
# 16    8.814124             MonthlyIncome
# 17    1.018111               MonthlyRate
# 18         inf        NumCompaniesWorked
# 19         NaN                    Over18
# 20    1.029225                  OverTime
# 21    2.318962         PercentSalaryHike
# ...

# %% [markdown]
# It looks fine as all the values are <10.

# %% [markdown]
# ### Data Modelling

# %%
#Finding best Random State
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu = 0
maxRS = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state=i)
    RFR = RandomForestClassifier()
    RFR.fit(x_train, y_train)
    pred = RFR.predict(x_test)
    acc = accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
        
print("Best accuracy score is", maxAccu, "at random_state", maxRS)
# Out:
# Best accuracy score is 0.8956916099773242 at random_state 26

# %% [markdown]
# ### Creating Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state=maxRS)

# %% [markdown]
# ### Classification Algorithms

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### Random Forest Classifier

# %%
#Checking accuracy for Random Forest Classifier
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC = RFC.predict(x_test)
print(accuracy_score(y_test, predRFC))
print(confusion_matrix(y_test, predRFC))
print(classification_report(y_test, predRFC))
# Out:
# 0.8843537414965986
# [[376   5]
#  [ 46  14]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.99      0.94       381
#          1.0       0.74      0.23      0.35        60
#
#     accuracy                           0.88       441
#    macro avg       0.81      0.61      0.65       441
# weighted avg       0.87      0.88      0.86       441

# %% [markdown]
# #### Extra Trees Classifier

# %%
#Checking accuracy for Extra Trees Classifier
ET = ExtraTreesClassifier()
ET.fit(x_train, y_train)
predET = ET.predict(x_test)
print(accuracy_score(y_test, predET))
print(confusion_matrix(y_test, predET))
print(classification_report(y_test, predET))
# Out:
# 0.8934240362811792
# [[378   3]
#  [ 44  16]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.99      0.94       381
#          1.0       0.84      0.27      0.41        60
#
#     accuracy                           0.89       441
#    macro avg       0.87      0.63      0.67       441
# weighted avg       0.89      0.89      0.87       441

# %% [markdown]
# #### Logistic Regression

# %%
#Checking accuracy for Logistic Regression  
LR = LogisticRegression()
LR.fit(x_train, y_train)
predLR = LR.predict(x_test)
print(accuracy_score(y_test, predLR))
print(confusion_matrix(y_test, predLR))
print(classification_report(y_test, predLR))
# Out:
# 0.8979591836734694
# [[370  11]
#  [ 34  26]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.97      0.94       381
#          1.0       0.70      0.43      0.54        60
#
#     accuracy                           0.90       441
#    macro avg       0.81      0.70      0.74       441
# weighted avg       0.89      0.90      0.89       441

# %% [markdown]
# #### SVC

# %%
#Checking accuracy for SVC
SV = SVC()
SV.fit(x_train, y_train)
predSV = SV.predict(x_test)
print(accuracy_score(y_test, predSV))
print(confusion_matrix(y_test, predSV))
print(classification_report(y_test, predSV))
# Out:
# 0.9002267573696145
# [[376   5]
#  [ 39  21]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.99      0.94       381
#          1.0       0.81      0.35      0.49        60
#
#     accuracy                           0.90       441
#    macro avg       0.86      0.67      0.72       441
# weighted avg       0.89      0.90      0.88       441

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
#Checking accuracy for Gradient Boosting  Classifier
GBC = GradientBoostingClassifier()
GBC.fit(x_train, y_train)
predGBC = GBC.predict(x_test)
print(accuracy_score(y_test, predGBC))
print(confusion_matrix(y_test, predGBC))
print(classification_report(y_test, predGBC))
# Out:
# 0.8934240362811792
# [[373   8]
#  [ 39  21]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.98      0.94       381
#          1.0       0.72      0.35      0.47        60
#
#     accuracy                           0.89       441
#    macro avg       0.81      0.66      0.71       441
# weighted avg       0.88      0.89      0.88       441

# %% [markdown]
# #### Ada Boost Classifier

# %%
#Checking accuracy for Ada Boost  Classifier
ABC = AdaBoostClassifier()
ABC.fit(x_train, y_train)
predABC = ABC.predict(x_test)
print(accuracy_score(y_test, predABC))
print(confusion_matrix(y_test, predABC))
print(classification_report(y_test, predABC))
# Out:
# 0.8798185941043084
# [[369  12]
#  [ 41  19]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.97      0.93       381
#          1.0       0.61      0.32      0.42        60
#
#     accuracy                           0.88       441
#    macro avg       0.76      0.64      0.68       441
# weighted avg       0.86      0.88      0.86       441

# %% [markdown]
# #### Bagging Classifier

# %%
#Checking accuracy for Bagging  Classifier
BC = BaggingClassifier()
BC.fit(x_train, y_train)
predBC = BC.predict(x_test)
print(accuracy_score(y_test, predBC))
print(confusion_matrix(y_test, predBC))
print(classification_report(y_test, predBC))
# Out:
# 0.8684807256235828
# [[368  13]
#  [ 45  15]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.97      0.93       381
#          1.0       0.54      0.25      0.34        60
#
#     accuracy                           0.87       441
#    macro avg       0.71      0.61      0.63       441
# weighted avg       0.84      0.87      0.85       441

# %% [markdown]
# #### KNN

# %%
#Checking accuracy for KNN
KN = KNeighborsClassifier()
KN.fit(x_train, y_train)
predKN = KN.predict(x_test)
print(accuracy_score(y_test, predKN))
print(confusion_matrix(y_test, predKN))
print(classification_report(y_test, predKN))
# Out:
# 0.8752834467120182
# [[377   4]
#  [ 51   9]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.99      0.93       381
#          1.0       0.69      0.15      0.25        60
#
#     accuracy                           0.88       441
#    macro avg       0.79      0.57      0.59       441
# weighted avg       0.86      0.88      0.84       441

# %% [markdown]
# #### Decision Tree Classifier

# %%
#Checking accuracy for Decision Tree Classification
DT = DecisionTreeClassifier()
DT.fit(x_train, y_train)
predDT = DT.predict(x_test)
print(accuracy_score(y_test, predDT))
print(confusion_matrix(y_test, predDT))
print(classification_report(y_test, predDT))
# Out:
# 0.8117913832199547
# [[328  53]
#  [ 30  30]]
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89       381
#          1.0       0.36      0.50      0.42        60
#
#     accuracy                           0.81       441
#    macro avg       0.64      0.68      0.65       441
# weighted avg       0.84      0.81      0.82       441

# %% [markdown]
# We can see Logistic Regression gives the best result of 90%.

# %% [markdown]
# ### Cross Validation Score

# %%
#Checking cv score Random Forest Classifier
score = cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predRFC) - score.mean())
# Out:
# [0.85034014 0.86054422 0.86734694 0.8537415  0.85714286]
# 0.8578231292517007
# Difference between Accuracy score and cross validation score is -  0.026530612244897944

# %%
#Checking cv score Extra Trees Classifier
score = cross_val_score(ET,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predET) - score.mean())
# Out:
# [0.84353741 0.86054422 0.85714286 0.8537415  0.85714286]
# 0.8544217687074829
# Difference between Accuracy score and cross validation score is -  0.03900226757369629

# %%
#Checking cv score Logistic Regression
score = cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predLR) - score.mean())
# Out:
# [0.8707483  0.86734694 0.86734694 0.86394558 0.88095238]
# 0.8700680272108844
# Difference between Accuracy score and cross validation score is -  0.027891156462585

# %%
#Checking cv score SVC
score = cross_val_score(SV,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predSV) - score.mean())
# Out:
# [0.86054422 0.8537415  0.8707483  0.86734694 0.8707483 ]
# 0.864625850340136
# Difference between Accuracy score and cross validation score is -  0.0356009070294786

# %%
#Checking cv score Gradient Boosting Classifier
score = cross_val_score(GBC,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predGBC) - score.mean())
# Out:
# [0.85034014 0.87414966 0.87414966 0.85714286 0.86054422]
# 0.863265306122449
# Difference between Accuracy score and cross validation score is -  0.030158730158730163

# %%
#Checking cv score Ada Boost Classifier
score = cross_val_score(ABC,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predABC) - score.mean())
# Out:
# [0.83673469 0.86734694 0.85714286 0.88435374 0.84013605]
# 0.8571428571428571
# Difference between Accuracy score and cross validation score is -  0.02267573696145131

# %%
#Checking cv score Bagging Classifier
score = cross_val_score(BC,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predBC) - score.mean())
# Out:
# [0.81632653 0.84693878 0.83673469 0.85034014 0.88095238]
# 0.8462585034013606
# Difference between Accuracy score and cross validation score is -  0.022222222222222254

# %%
#Checking cv score KNeighbors Classifier
score = cross_val_score(KN,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predKN) - score.mean())
# Out:
# [0.84013605 0.83673469 0.84693878 0.8537415  0.85714286]
# 0.846938775510204
# Difference between Accuracy score and cross validation score is -  0.028344671201814164

# %%
#Checking cv score Decision Classifier
score = cross_val_score(DT,x,y)
print(score)
print(score.mean())
print("Difference between Accuracy score and cross validation score is - ", accuracy_score(y_test, predDT) - score.mean())
# Out:
# [0.78231293 0.79931973 0.81632653 0.75510204 0.78911565]
# 0.7884353741496598
# Difference between Accuracy score and cross validation score is -  0.023356009070294892

# %% [markdown]
# Here, Logistic Regression works best with the least difference between accuracy and cross validation.

# %% [markdown]
# Since Logistic Regression does not have any critical hyper parameters to tune, so we do not need to tune parameters here.
# This is our conclusion and Logistic Regression is our best model.

# %% [markdown]
# ### Documentation

# %% [markdown]
# - First we imported necessary libraries.
# - We did EDA and all the steps involved in it.
# - We checked fpr Correlation between features.
# - We visualized the data and compared features with label.
# - We checked for Outliers and Skewness and removed it.
# - We separated features and label.
# - We scaled the features using Standard Scaler.
# - We checked for VIF values.
# - We started modelling our data.
# - Created Train Test Split.
# - Imported certain Classification Algorithms.
# - Checked for Accuracy score and all.
# - Checked for Cross Validation score.
# - And as Logistic Regression does not have any critical parameters to tune, so didn't do any hyper parameter tuning.
# That's it!
